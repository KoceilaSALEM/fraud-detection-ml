# %%
import duckdb
import pandas as pd
import numpy as np
from pathlib import Path

# ========= CONFIG =========
CSV_PATH = r"C:\Users\RQKB6834\Downloads\OM_Koceila .csv\OM_Koceila.csv"
SEP = "|"
ENCODING = "latin-1"

OUT_DIR = Path("./outputs")
OUT_DIR.mkdir(parents=True, exist_ok=True)

OUT_FEATURES_PARQUET = OUT_DIR / "daily_service_features.parquet"
OUT_FEATURES_CSV = OUT_DIR / "daily_service_features.csv"

# Top services vus au notebook 01 (ajustable)
SERVICES_MODEL = ["RC", "MERCHPAY", "CASHIN", "CASHOUT", "P2P", "ROLLBACK"]

print("CSV:", CSV_PATH)
print("Output:", OUT_FEATURES_PARQUET)
# Out:
# CSV: C:\Users\RQKB6834\Downloads\OM_Koceila .csv\OM_Koceila.csv
# Output: outputs\daily_service_features.parquet
